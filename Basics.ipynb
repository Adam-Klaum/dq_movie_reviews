# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss
# %matplotlib inline

# %%
movies = pd.read_csv('fandango_score_comparison.csv')

# %%
movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
ax = movies['Metacritic_norm_round'].hist(bins=5)
ax.set_xlim(0,5)
# Out:
# (0, 5)

# %%
ax = movies['Fandango_Stars'].hist(bins=5)
ax.set_xlim(0,5)
# Out:
# (0, 5)

# %% [markdown]
# Looking at the histograms for Metacritic vs. Fandango it is obvious that Fandago's ratings are skewed quite high and are not at all a normal distribution.

# %%
f_mean = movies['Fandango_Stars'].mean()
m_mean = movies['Metacritic_norm_round'].mean()
f_median = movies['Fandango_Stars'].median()
m_median = movies['Metacritic_norm_round'].median()
f_std = np.std(movies['Fandango_Stars'])
m_std = np.std(movies['Metacritic_norm_round'])

# %%
stats = pd.DataFrame([['Fandango', f_mean, f_median, f_std],
                      ['Metacritic', m_mean, m_median, m_std]],
                     columns=['Provider', 'Mean', 'Median', 'Std. Dev'])

# %%
stats
# Out:
#      Provider      Mean  Median  Std. Dev
# 0    Fandango  4.089041     4.0  0.538532
# 1  Metacritic  2.972603     3.0  0.987561

# %%
plt.scatter(movies['Fandango_Stars'], movies['Metacritic_norm_round'])
plt.xlim(0,5)
plt.ylim(0,5)
# Out:
# (0, 5)

# %%
movies['fm_diff'] = movies['Metacritic_norm_round'] - movies['Fandango_Stars']

# %%
movies['fm_diff'] = movies['fm_diff'].apply(lambda x: np.absolute(x))

# %%
movies.sort_values(by=['fm_diff'], ascending=False, inplace=True)

# %%
movies.head()
# Out:
#                         FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 3     Do You Believe? (2015)              18                   84          22
# 85         Little Boy (2015)              20                   81          30
# 47              Annie (2014)              27                   61          33
# 19             Pixels (2015)              17                   54          27
# 134  The Longest Ride (2015)              31                   73          33
#
#      Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 3                4.7   5.4             5.0                   4.5     0.90
# 85               5.9   7.4             4.5                   4.3     1.00
# 47               4.8   5.2             4.5                   4.2     1.35
# 19               5.3   5.6             4.5                   4.1     0.85
# 134              4.8   7.2             4.5                   4.5     1.55
#
# ...

# %%
r_value, _ = ss.pearsonr(movies['Fandango_Stars'], movies['Metacritic_norm_round'])

# %%
r_value
# Out:
# 0.17844919073895918

# %%
slope, intercept, rvalue, pvalue, stderr = ss.linregress(movies['Metacritic_norm_round'], movies['Fandango_Stars'])

# %%
pred_3 = 3 * slope + intercept

# %%
pred_3
# Out:
# 4.0917071528212041

# %%
pred_1 = 1 * slope + intercept
pred_5 = 5 * slope + intercept

# %%
pred_1
# Out:
# 3.897084996873347

# %%
pred_5
# Out:
# 4.2863293087690604

# %%
plt.scatter(movies['Fandango_Stars'], movies['Metacritic_norm_round'])
plt.xlim(1,5)
plt.ylim(1,5)
plt.plot([1.0, 5.0], [pred_1, pred_5], color='orange')
